# %%
with open('/tmp/data/magone/mag_papers_1_clean_small.txt') as f:
    lines = f.readlines()
    for line in lines[0:1000]:
        print(line)
# Out:
# {"title": "Oraciones finales en hebreo rab\u00ednico", "lang": "es", "year": 1992, "authors": [{"name": "Miguel P\u00e9rez Fern\u00e1ndez"}], "issue": "1", "page_end": "199", "publisher": "Instituto de Lenguas y Culturas del Mediterr\u00e1neo y Oriente Pr\u00f3ximo -ILC", "url": ["https://dialnet.unirioja.es/servlet/articulo?codigo=3937681", "http://dialnet.unirioja.es/servlet/articulo?codigo=3937681"], "id": "0184e880-16dc-4eac-bb3d-cc4b7ed30540", "keywords": ["filologias", "grupo a", "grupo b", "filologias clasicas y antiguas"], "page_start": "193", "venue": "Sefarad", "volume": "52"}
#
# ...
