# %%
import json
import time
import pandas as pd
from py2neo import Graph, Node, Relationship
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.tree import DecisionTreeClassifier

# %%
graph = Graph("bolt://neo4j-allquanta:7687", auth=('neo4j','myneo'))
print("Connected to graph database with {:,} nodes and {:,} relationships!".format(
    graph.database.primitive_counts['NumberOfNodeIdsInUse'], 
    graph.database.primitive_counts['NumberOfRelationshipIdsInUse']))
# Out:
# Connected to graph database with 278,432,359 nodes and 1,844,501,832 relationships!

# %%
years_to_use = 3
start_year = 2009
end_year = 2013

print("Getting dataset...", end=" ")
cites_str = ',\n    '.join(['CASE WHEN {} < q.year THEN NULL ELSE SIZE((q)<-[:CITES]-(:Quanta {{year: {}}})) END as c{}'.format(
    yr, yr, yr) for yr in range(start_year, end_year+1)])
tspr_str = ',\n    '.join(['q.tspr{} as tspr{}'.format(
    yr, yr) for yr in range(start_year, end_year+1)])
query = """
MATCH (q:Quanta)
WHERE 
    (q.doctype='Journal') AND 
    (q.lang='en') AND 
    EXISTS(q.fos) AND 
    (q.year>={} AND q.year <= {}) AND
    q.venue='Nature'   # ADDED THIS LINE IN FOR NATURE ONLY VENUE
RETURN
    q.year as year,
    q.title as title,
    q.id as id,
    {},
    {}
LIMIT 1000
""".format(start_year, end_year-years_to_use, tspr_str, cites_str)
print(query)
query_start_time = time.time()
df = graph.run(query).to_data_frame()
print("Done ({:.2f} minutes).".format((time.time()-query_start_time)/60))
# Out:
# Getting dataset...
# MATCH (q:Quanta)
# WHERE
#     (q.doctype='Journal') AND
#     (q.lang='en') AND
#     EXISTS(q.fos) AND
#     (q.year>=2009 AND q.year <= 2010) AND
#     q.venue='Nature'
# RETURN
#     q.year as year,
#     q.title as title,
#     q.id as id,
#     q.tspr2009 as tspr2009,
#     q.tspr2010 as tspr2010,
#     q.tspr2011 as tspr2011,
#     q.tspr2012 as tspr2012,
#     q.tspr2013 as tspr2013,
#     CASE WHEN 2009 < q.year THEN NULL ELSE SIZE((q)<-[:CITES]-(:Quanta {year: 2009})) END as c2009,
#     CASE WHEN 2010 < q.year THEN NULL ELSE SIZE((q)<-[:CITES]-(:Quanta {year: 2010})) END as c2010,
#     CASE WHEN 2011 < q.year THEN NULL ELSE SIZE((q)<-[:CITES]-(:Quanta {year: 2011})) END as c2011,
#     CASE WHEN 2012 < q.year THEN NULL ELSE SIZE((q)<-[:CITES]-(:Quanta {year: 2012})) END as c2012,
#     CASE WHEN 2013 < q.year THEN NULL ELSE SIZE((q)<-[:CITES]-(:Quanta {year: 2013})) END as c2013
# LIMIT 1000
#
# Done (0.72 minutes).

# %%
# appends class to top 5 percentile making into classification problem

threshold = df.quantile(0.95).tspr2013
df['class'] = df.apply(lambda row: 0 if row.tspr2013 < threshold else 1, axis=1)

# %%
# extract features for each paper
df.apply(lambda row: NaN not in row)
# Out:
#      c2009  c2010  c2011  c2012  c2013                                    id  \
# 0     31.0     52     63     74     76  003e7f6d-ba6f-4e72-8d05-9fd2a35a390c
# 11                   Technology transfer on the table.  0.150000  0.150000
# 12   In Retrospect: The earliest picture of evolution?  0.150000  0.150000
# 13                         NIH nominee draws scrutiny.  0.181875  0.181875
# 14   European Commission clarifies the rules for re...       NaN  0.150000
# 15   Phosphate oxygen isotopic evidence for a tempe...       NaN  0.150000
# 16   International peer review improved Irish resea...  0.150000  0.150000
# 17                   Mice made from induced stem cells  0.150000  0.150000
# 18       Pioneers of plant genetics to flower on stage       NaN  0.150000
# 19           A reality check for personalized medicine       NaN  0.150000
# 20          Astronomers witness biggest star explosion  0.150000  0.150000
# 21                                  Ahead of the pack.  0.150000  0.150000
# 22                        Venus crater debate heats up       NaN  0.150000
# 23                                  Why music moves us       NaN  0.150000
# 24   TCR-peptide-MHC interactions in situ show acce...       NaN  0.150000
# 25   Australia's 'rainbow coalition' focuses on cli...       NaN  0.150000
# 26            Space telescope suffers instrument delay  0.150000  0.150000
# 27               Non-proliferation: A nuclear exchange       NaN  0.150000
# 28                                A fresh take on food  0.277500  0.277500
# 29      Newsmaker of the year: In the eye of the storm       NaN  0.150000
# ..                                                 ...       ...       ...
# 970        The late Precambrian greening of the Earth.  0.277500  0.277500
# 971  Structural biology: Proteins in dynamic equili...       NaN  0.150000
# 972                        Gravitational astronomy 101  0.150000  0.150000
# 973            Volatile accretion history of the Earth       NaN  0.150000
# 974                          Societies evolve in steps       NaN  0.150000
# 975       Transcription: Enhancers make non-coding RNA       NaN  0.150000
# 976                          What causes schizophrenia  0.150000  0.150000
# 977               Dark energy rips cosmos and agencies  0.150000  0.150000
# 978  Wnt11 patterns a myocardial electrical gradien...       NaN  0.150000
# 979  Discovery of a sexual cycle in the opportunist...  0.277500  0.277500
# 980              Report row ousts top Indian scientist  0.150000  0.150000
# 981  Forensics: stronger scientific scrutiny needed...       NaN  0.150000
# 982          Chromosome crosstalk in three dimensions.  0.150000  0.150000
# 983                 How accurate are cancer cell lines       NaN  0.150000
# 984              Primate study halted by US university  0.150000  0.150000
# 985          Cell biology: A sensor for calcium uptake       NaN  0.150000
# 986  Non-radial oscillation modes with long lifetim...  0.150000  0.277500
# 987              Genome 'census' reveals hidden riches       NaN  0.150000
# 988                     Soil map digs under the tundra       NaN  0.150000
# 989  Striations, duration, migration and tidal resp...       NaN  0.277500
# 990             Pulsar watchers race for gravity waves       NaN  0.150000
# 991  Quantum physics: Quantum leaps in the solid state       NaN  0.150000
# 992                  Brazil mulls major climate action  0.150000  0.150000
# 993         Complex systems: Foreseeing tipping points       NaN  0.150000
# 994  Sugar transporters for intercellular exchange ...       NaN  0.213750
# 995            Innovation in Europe - three questions.       NaN  0.150000
# 996  Response and Resistance to MEK Inhibition in L...  0.150000  0.150000
# 997  Replacing underperforming protected areas achi...       NaN  0.213750
# 998  Incoming chief to tackle woes of US food and d...  0.150000  0.150000
# 999               Human genomics: The genome finishers  0.150000  0.150000
#
#      tspr2011  tspr2012  tspr2013  year  class
