# %%
import json
import time
from functools import reduce

import pandas as pd
import numpy as np

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from tqdm.autonotebook import tqdm

from py2neo import Graph, Node, Relationship

# %%
public_address = '54.174.175.98'
graph = Graph('bolt://{}:7687'.format(public_address), auth=('neo4j','myneo'))

def run_query(query, graph, print_query=False, run_query=True, 
              print_only=False, to_df=False, verbose=True):
    df = 1
    if print_only: 
        print_query = True
        run_query = False
    start_time = time.time()
    if print_query:
        print(query)
    if run_query:
        if to_df:
            df = graph.run(query).to_data_frame()
        else:
            graph.run(query)
    end_time = time.time()
    minutes_elapsed = (end_time-start_time)/60
    if verbose:
        print("Query completed in {:.2f} minutes.".format(minutes_elapsed))
    return df

# %%
min_year, max_year = 1900, 2020
for y in tqdm(range(min_year, max_year+1)):
    
    print("{}...".format(y))
    
    # Write DeepGL scores considering all nodes from year <= y
    query = """
    CALL embedding.deepWalk('
    MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
    WHERE y.year <= {y}
    MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
    WHERE z.year <= {y} AND ((p)-[:CITES]->(q))
    RETURN id(q) as id
    ','
    MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
    RETURN id(q1) AS source, id(q2) AS target
    ',{{graph:'cypher', write:true, writeProperty:"temporary"}});
    """.format(y=y)
    run_query(query, graph, print_only=True)
    
#     # Calculate reference set statistics for all years <= y
#     query = """
#     MATCH (y:Year)
#     WHERE y.year <= {}
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE (z.year<=y.year+1) AND (z.year>=y.yearvalue-1)
#     RETURN y.year as year, avg(q.temporary) as avg, stdev(q.temporary) AS std
#     ORDER BY y.yearvalue DESC;
#     """.format(y)
#     df = run_query(query, graph, to_df=True, print_only=True)
    
#     # Normalize score for each Quanta from year <= y
#     df['avg_str'] = df.apply(lambda row: 'WHEN {:.0f} THEN {}'.format(row['year'], row['avg']), axis=1)
#     df['std_str'] = df.apply(lambda row: 'WHEN {:.0f} THEN {}'.format(row['year'], row['std']), axis=1)
#     avg_case_str = 'CASE q.year ' + reduce(lambda a,b:'{} {}'.format(a,b), df['avg_str']) + ' END'
#     std_case_str = 'CASE q.year ' + reduce(lambda a,b:'{} {}'.format(a,b), df['std_str']) + ' END'
#     query = """
#     CALL apoc.periodic.iterate('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(z:Year) 
#     WHERE z.year <= {}
#     RETURN q
#     ','
#     SET q.temporary = ABS(q.temporary-{})/{}
#     ',{{batchSize:10000, parallel:true}});
#     """.format(y, avg_case_str, std_case_str)
#     run_query(query, graph, print_only=True)
    
#     # Write scores to METRICS_IN relationship
#     query = """
#     CALL apoc.periodic.iterate('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(z:Year) 
#     WHERE z.year <= {}
#     RETURN q
#     ','
#     MATCH (y:Year)
#     WHERE y.year = {}
#     MERGE (q)-[m:METRICS_IN]->(y)
#     SET m.timeScaledPageRank = q.temporary
#     ',{{batchSize:10000, parallel:true}});
#     """.format(y,y)
#     run_query(query, graph, print_only=True)
# Out:
# HBox(children=(IntProgress(value=0, max=121), HTML(value='')))
# 1900...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1900
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1900 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1901...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1901
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1901 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1902...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1902
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1902 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1903...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1903
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1903 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1904...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1904
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1904 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1905...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1905
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1905 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1906...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1906
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1906 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1907...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1907
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1907 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1908...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1908
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1908 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1909...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1909
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1909 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1910...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1910
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1910 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1911...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1911
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1911 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1912...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1912
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1912 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1913...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1913
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1913 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1914...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1914
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1914 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1915...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1915
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1915 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1916...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1916
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1916 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1917...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1917
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1917 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1918...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1918
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1918 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1919...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1919
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1919 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1920...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 1920
#     MATCH (p:Quanta)-[:PUBLISHED_IN]->(z:Year)
#     WHERE z.year <= 1920 AND ((p)-[:CITES]->(q))
#     RETURN id(q) as id
#     ','
#     MATCH (q1:Quanta)-[:CITES]->(q2:Quanta)
#     RETURN id(q1) AS source, id(q2) AS target
#     ',{graph:'cypher', write:true, writeProperty:"temporary"});
#
# Query completed in 0.00 minutes.
# 1921...
#
#     CALL embedding.deepWalk('
#     MATCH (q:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE y.year <= 