# %%
import json
import time
from functools import reduce

import pandas as pd
import numpy as np

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from tqdm.autonotebook import tqdm

from py2neo import Graph, Node, Relationship

# %%
graph = Graph("bolt://dev_neo4j:7687", auth=('neo4j','myneo'))

n_nodes = graph.database.primitive_counts['NumberOfNodeIdsInUse']
n_relationships = graph.database.primitive_counts['NumberOfRelationshipIdsInUse']
print("Connected to graph database with {:,} nodes and {:,} relationships!".format
     (n_nodes, n_relationships))

def run_query(query, graph, print_query=False, run_query=True, 
              print_only=False, to_df=False, verbose=True):
    df = 1
    if print_only: 
        print_query = True
        run_query = False
    start_time = time.time()
    if print_query:
        print(query)
    if run_query:
        if to_df:
            df = graph.run(query).to_data_frame()
        else:
            graph.run(query)
    end_time = time.time()
    minutes_elapsed = (end_time-start_time)/60
    if verbose:
        print("Query completed in {:.2f} minutes.".format(minutes_elapsed))
    return df
# Out:
# Connected to graph database with 370,269,897 nodes and 220,155,390 relationships!

# %%
# Write edge lists
min_year, max_year = 1900, 2020
for y in tqdm(range(min_year, max_year+1)):
    print("{}...".format(y))
        
    # Write edge list for graph at year=y
    query = """
    CALL apoc.export.csv.query('
    MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
    WHERE z.value<={year} AND y.value<={year}
    RETURN id(a) as source, id(b) as target
    ','{out}',
    {{quotes:false}});
    """.format(year=y, out='/import/embeddings/quanta.{}.edgelist'.format(y))
    run_query(query, graph, print_only=True)
# Out:
# HBox(children=(IntProgress(value=0, max=121), HTML(value='')))
# 1900...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1900 AND y.value<=1900
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1900.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1901...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1901 AND y.value<=1901
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1901.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1902...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1902 AND y.value<=1902
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1902.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1903...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1903 AND y.value<=1903
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1903.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1904...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1904 AND y.value<=1904
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1904.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1905...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1905 AND y.value<=1905
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1905.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1906...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1906 AND y.value<=1906
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1906.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1907...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1907 AND y.value<=1907
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1907.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1908...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1908 AND y.value<=1908
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1908.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1909...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1909 AND y.value<=1909
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1909.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1910...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1910 AND y.value<=1910
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1910.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1911...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1911 AND y.value<=1911
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1911.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1912...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1912 AND y.value<=1912
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1912.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1913...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1913 AND y.value<=1913
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1913.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1914...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1914 AND y.value<=1914
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1914.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1915...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1915 AND y.value<=1915
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1915.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1916...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1916 AND y.value<=1916
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1916.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1917...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1917 AND y.value<=1917
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1917.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1918...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1918 AND y.value<=1918
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1918.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1919...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1919 AND y.value<=1919
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1919.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1920...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1920 AND y.value<=1920
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1920.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1921...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1921 AND y.value<=1921
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1921.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1922...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1922 AND y.value<=1922
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1922.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1923...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1923 AND y.value<=1923
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1923.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1924...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1924 AND y.value<=1924
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1924.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1925...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1925 AND y.value<=1925
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1925.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1926...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1926 AND y.value<=1926
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1926.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1927...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1927 AND y.value<=1927
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1927.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1928...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1928 AND y.value<=1928
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1928.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 

#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1991 AND y.value<=1991
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1991.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1992...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1992 AND y.value<=1992
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1992.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1993...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1993 AND y.value<=1993
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1993.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1994...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1994 AND y.value<=1994
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1994.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1995...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1995 AND y.value<=1995
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1995.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1996...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1996 AND y.value<=1996
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1996.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1997...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1997 AND y.value<=1997
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1997.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1998...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1998 AND y.value<=1998
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1998.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 1999...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=1999 AND y.value<=1999
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.1999.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2000...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2000 AND y.value<=2000
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2000.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2001...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2001 AND y.value<=2001
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2001.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2002...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2002 AND y.value<=2002
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2002.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2003...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2003 AND y.value<=2003
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2003.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2004...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2004 AND y.value<=2004
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2004.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2005...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2005 AND y.value<=2005
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2005.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2006...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2006 AND y.value<=2006
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2006.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2007...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2007 AND y.value<=2007
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2007.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2008...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2008 AND y.value<=2008
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2008.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2009...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2009 AND y.value<=2009
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2009.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2010...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2010 AND y.value<=2010
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2010.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2011...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2011 AND y.value<=2011
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2011.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2012...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2012 AND y.value<=2012
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2012.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2013...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2013 AND y.value<=2013
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2013.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2014...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2014 AND y.value<=2014
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2014.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2015...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2015 AND y.value<=2015
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2015.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2016...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2016 AND y.value<=2016
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2016.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2017...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2017 AND y.value<=2017
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2017.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2018...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2018 AND y.value<=2018
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2018.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2019...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2019 AND y.value<=2019
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2019.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.
# 2020...
#
#     CALL apoc.export.csv.query('
#     MATCH (z:Year)<-[:PUBLISHED_IN]-(a:Quanta)-[:CITES]->(b:Quanta)-[:PUBLISHED_IN]->(y:Year)
#     WHERE z.value<=2020 AND y.value<=2020
#     RETURN id(a) as source, id(b) as target
#     ','/import/embeddings/quanta.2020.edgelist',
#     {quotes:false});
#
# Query completed in 0.00 minutes.

# %%
# Replace commas with spaces
find . -name 'quanta.*.edgelist' -exec sed -i "s/,/ /g" {} \;

# %%
# Delete first row TODO update to first two rows and add header:false to LOAD CSV
for filename in quanta.*.edgelist; do
     tail -n +2 "$filename" > "$filename.tmp"
     mv -f "$filename.tmp" "$filename" 
done

# %%
# Run node2vec
for filename in quanta.*.edgelist; do
     ./node2vec -i:"$filename" -o:"$filename.emb" -d:10 -dr -v
done

# %%
# Import results to graph
min_year, max_year = 1900, 1990
for y in tqdm(range(min_year, max_year+1)):
    print("{}...".format(y))
    
    edgelist = '/import/embeddings/quanta.{}.edgelist'.format(y)
    
    # Write edge list for graph at year=y
    query = """
    CALL apoc.load.csv('/import/embeddings/quanta.{year}.edgelist.emb', {{sep:" "}})
    YIELD list 
    WITH apoc.convert.toInteger(head(list)) as nodeId, 
        [x IN tail(list) | apoc.convert.toFloat(x)] AS embedding
    MATCH (n) WHERE id(n)=nodeId
    MATCH (y:Year) WHERE y.value={year}
    MERGE(n)-[r:METRICS_IN]->(y)
    SET r.node2vec=embedding
    """.format(year=y)
    run_query(query, graph, print_only=False)
# Out:
# HBox(children=(IntProgress(value=0, max=91), HTML(value='')))
# 1900...
#
#     CALL apoc.load.csv('/import/embeddings/quanta.